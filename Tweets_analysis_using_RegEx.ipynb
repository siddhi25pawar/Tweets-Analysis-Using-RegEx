# %% [markdown]
# TABLE OF CONTENTS
# 1.About the datasets
# 2.Regex for cleaning Text data
# 3.Regex for Text data Extraction
# 4.Regex challenge

# %%
import pandas as pd
df=pd.read_csv("tweets.csv",encoding="ISO-8859-1")
df.head()
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  5  RT @satishacharya: Reddy Wedding! @mail_today ...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2016-11-23 18:40:30      False
# 1      False              0       NaN  2016-11-23 18:40:29      False
# 2      False              0       NaN  2016-11-23 18:40:03      False
# 3      False              0       NaN  2016-11-23 18:39:59      False
# 4      False              0       NaN  2016-11-23 18:39:39      False
#
#    replyToSID            id  replyToUID  \
# 0         NaN  8.014957e+17         NaN
# 1         NaN  8.014957e+17         NaN
# ...

# %% [markdown]
# 2.Regex for cleaning text data

# %%
# looking for some tweets
for index,tweet in enumerate(df["text"][10:15]):
  print(index+1,".",tweet)
# Out:
# 1 . Many opposition leaders are with @narendramodi on the #Demonetization
# And respect their decision,but support opposition just b'coz of party
# 2 . RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r
# 3 . @Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders.
# 4 . RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# 5 . RT @sona2905: When I explained #Demonetization to myself and tried to put it down in my words which are not laced with any heavy technical

# %%
import re

# %% [markdown]
# a.Removing RT

# %%
text="RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r"
clean_text=re.sub('RT','',text)
print("Text before:\n",text)
print("Text after:\n",clean_text)
# Out:
# Text before:
#  RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r
# Text after:
#   @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r

# %%
# Tweets before removal
df['text'].head()
# Out:
# 0    RT @rssurjewala: Critical question: Was PayTM ...
# 1    RT @Hemant_80: Did you vote on #Demonetization...
# 2    RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3    RT @ANI_news: Gurugram (Haryana): Post office ...
# 4    RT @satishacharya: Reddy Wedding! @mail_today ...
# Name: text, dtype: object

# %%
df['text']=df['text'].apply(lambda x:re.sub('RT','',x))

# %%
df['text'].head()
# Out:
# 0     @rssurjewala: Critical question: Was PayTM in...
# 1     @Hemant_80: Did you vote on #Demonetization o...
# 2     @roshankar: Former FinSec, RBI Dy Governor, C...
# 3     @ANI_news: Gurugram (Haryana): Post office em...
# 4     @satishacharya: Reddy Wedding! @mail_today ca...
# Name: text, dtype: object

# %% [markdown]
# b.Removing <u+..> like symbols from single tweets

# %%
text="@Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders"
clean_text=re.sub('U\+[A-Z0-9]+>','',text)
print("Text before :\n",text)
print("text after:\n",clean_text)
# Out:
# Text before :
#  @Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders
# text after:
#  @Jaggesh2 Bharat band on 28??<ed><<<ed><<Those who  are protesting #demonetization  are all different party leaders
# <>:2: SyntaxWarning: invalid escape sequence '\+'
# <>:2: SyntaxWarning: invalid escape sequence '\+'
# /tmp/ipython-input-1954325833.py:2: SyntaxWarning: invalid escape sequence '\+'
#   clean_text=re.sub('U\+[A-Z0-9]+>','',text)

# %%
# Removing <U+..> like symbol from all the tweets
df['text']=df['text'].apply(lambda x: re.sub('<U\+[A-Z0-9]+>','',x))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\+'
# <>:2: SyntaxWarning: invalid escape sequence '\+'
# /tmp/ipython-input-3091486132.py:2: SyntaxWarning: invalid escape sequence '\+'
#   df['text']=df['text'].apply(lambda x: re.sub('<U\+[A-Z0-9]+>','',x))

# %% [markdown]
# c.Fixing the & and &amp ;

# %%
#Replacing &amp with & in single tweet
text="RT @harshkkapoor: #DeMonetization survey results after 24 hours 5Lacs opinions Amazing response&amp; Commitment in fight against Blackmoney @na�"
clean_text=re.sub('&amp;','&',text)
print("Text before:\n", text)
print("Text after:\n",clean_text)
# Out:
# Text before:
#  RT @harshkkapoor: #DeMonetization survey results after 24 hours 5Lacs opinions Amazing response&amp; Commitment in fight against Blackmoney @na�
# Text after:
#  RT @harshkkapoor: #DeMonetization survey results after 24 hours 5Lacs opinions Amazing response& Commitment in fight against Blackmoney @na�

# %%
#Replacing all &amp with & in all the tewwts
df['text']=df['text'].apply(lambda x: re.sub('&amp','&',x))

# %% [markdown]
# 3.Regex for Text Data Extraction
#
# a.Extracting platform type of tweets

# %%
platform_count=df["statusSource"].value_counts()

# %%
platform_count
# Out:
# statusSource
# <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>                                        7642
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                                                          2548
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>                                          2093
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>                                          492
# <a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>                                                         263
#                                                                                                                             ...
# <a href="http://www.straitwaytruth.com" rel="nofollow">Charles Dowell Jr</a>                                                   1
# ...

# %%
#List platform that have more the 100 tweets
top_platforms=platform_count.loc[platform_count>100]
top_platforms
# Out:
# statusSource
# <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>    7642
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                      2548
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>      2093
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      492
# <a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>                     263
# <a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>                  178
# <a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>                    167
# <a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>        165
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>            139
# <a href="http://onlywire.com/" rel="nofollow">OnlyWire / Official App</a>                136
# ...

# %%
def platform_type(x):
  ser = re.search(r"android|iphone|web|windows|mobile|google|facebook|ipad|tweetdeck|onlywire", x, re.IGNORECASE)
  if ser:
      return ser.group()
  else:
    return None
# reset index of the series
top_platforms=top_platforms.reset_index()["statusSource"]
# extract platform types
top_platforms.apply(lambda x: platform_type(x))
# Out:
# 0       android
# 1           Web
# 2        iphone
# 3     tweetdeck
# 4        mobile
# 5        mobile
# 6      facebook
# 7          ipad
# 8       Windows
# 9      onlywire
# 10      Windows
# 11       mobile
# 12       google
# Name: statusSource, dtype: object

# %% [markdown]
# B.Extract first hashtag from tweets

# %%
text = "RT @Atheist_Krishna: The effect of #Demonetization !!\r\n. https://t.co/A8of7zh2f5"
hashtag=re.search('#\w+',text)

print("Tweet:\n",text)
print("Hashtag:\n",hashtag.group())
# Out:
# Tweet:
#  RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# Hashtag:
#  #Demonetization
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-3072744469.py:2: SyntaxWarning: invalid escape sequence '\w'
#   hashtag=re.search('#\w+',text)

# %%
# Extracting Multiple hastags
text="""RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo"""
hashtags=re.findall('#\w+',text)

print("Tweet:\n",text)
print("Hashtag:\n",hashtags)
# Out:
# Tweet:
#  RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# Hashtag:
#  ['#Doltiwal', '#JaiChandKejriwal', '#Demonetization']
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-1298997263.py:3: SyntaxWarning: invalid escape sequence '\w'
#   hashtags=re.findall('#\w+',text)

# %%
df['hashtag']=df['text'].apply(lambda x: re.findall('#\w+',x))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-1405674835.py:1: SyntaxWarning: invalid escape sequence '\w'
#   df['hashtag']=df['text'].apply(lambda x: re.findall('#\w+',x))

# %%
df[['text','hashtag']].head()
# Out:
#                                                 text  \
# 0   @rssurjewala: Critical question: Was PayTM in...
# 1   @Hemant_80: Did you vote on #Demonetization o...
# 2   @roshankar: Former FinSec, RBI Dy Governor, C...
# 3   @ANI_news: Gurugram (Haryana): Post office em...
# 4   @satishacharya: Reddy Wedding! @mail_today ca...
#
#                             hashtag
# 0                 [#Demonetization]
# 1                 [#Demonetization]
# 2                 [#Demonetization]
# 3                 [#demonetization]
# 4  [#demonetization, #ReddyWedding]

# %% [markdown]
# 4.Regex challenge
#
# a.removing urls
#
# b.extract top 100 mentions

# %%
Text="RT @satishacharya: Reddy Wedding! @mail_today cartoon #demonetization #ReddyWedding https://t.co/u7gLNrq31F"
text = re.sub(r"[^\x00-\x7F]+", "", text)
clean_text=re.sub("https://S+;",',',text)
print("Text before:\n", text)
print("Text after:\n",clean_text)
# Out:
# Text before:
#  RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# Text after:
#  RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo

# %%
#for all
df['text']=df['text'].apply(lambda x:re.sub('RT','',x))

# %%
df['text']=df['text'].apply(lambda x:re.sub("https://S+;",',',text))

# %%
df.head()
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 1           2  2  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 2           3  3  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 3           4  4  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 4           5  5  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2016-11-23 18:40:30      False
# 1      False              0       NaN  2016-11-23 18:40:29      False
# 2      False              0       NaN  2016-11-23 18:40:03      False
# 3      False              0       NaN  2016-11-23 18:39:59      False
# 4      False              0       NaN  2016-11-23 18:39:39      False
#
#    replyToSID            id  replyToUID  \
# 0         NaN  8.014957e+17         NaN
# 1         NaN  8.014957e+17         NaN
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0      X                                               text  \
# 14935       14936  14936  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 14936       14937  14937  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 14937       14938  14938  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 14938       14939  14939  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 14939       14940  14940  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
#
#        favorited  favoriteCount replyToSN              created  truncated  \
# 14935      False              0       NaN  2017-04-11 14:26:38      False
# 14936      False              0       NaN  2017-04-11 14:19:51       True
# 14937      False              0       NaN  2017-04-11 14:19:14      False
# 14938      False              0       NaN  2017-04-11 14:13:14      False
# 14939      False              1    Vidyut  2017-04-11 14:13:06       True
#
#          replyToSID            id  replyToUID  \
# ...

# %%
x="RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;�"
clean_text=re.findall(r'@\w+', x)
print("Text before:\n", text)
print("Text after:\n",clean_text)
# Out:
# Text before:
#  RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;�
# Text after:
#  ['@rssurjewala']

# %%
import re

df['mentions'] = df['text'].apply(lambda x: re.findall(r'@\w+', str(x)))
df_mentions = df.explode('mentions')
top_count = df_mentions['mentions'].value_counts()
print(top_count)
# Out:
# mentions
# @kapil_kausik    14940
# Name: count, dtype: int64

# %%
df['mentions']=df['text'].apply(lambda x: re.findall(r'@\w+',str(x)))
df_mentions=df.explode('mentions')

# %%
top_count = df_mentions['mentions'].value_counts()
print(top_count)
# Out:
# mentions
# @kapil_kausik    14940
# Name: count, dtype: int64

# %%
# Get the list of mentions that appear more than 100 times
top_mentions_list = top_count[top_count > 100].index.tolist()

# Filter the df_mentions DataFrame to keep only rows with mentions in the top_mentions_list
top_counts = df_mentions[df_mentions['mentions'].isin(top_mentions_list)]

display(top_counts)
# Out:
#        Unnamed: 0      X                                               text  \
# 0               1      1  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 1               2      2  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 2               3      3  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 3               4      4  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 4               5      5  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# ...           ...    ...                                                ...
# 14935       14936  14936  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 14936       14937  14937  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 14937       14938  14938  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 14938       14939  14939  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 14939       14940  14940  RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
#
# ...

# %% [markdown]
# **Alternative to find TOP 100**

# %%
def mention(x):
  found=re.findall(r'@\w+',x)
  if found:
    return found
  return None

# %%
arr=df['text'].apply(lambda x: mention(x))

# %%
#combining all mentions into list
mentions_arr=[]
for x in arr:
  if x!=None:
    mentions_arr.extend(x)

# %%
mentions_arr[:10]
# Out:
# ['@kapil_kausik',
#  '@kapil_kausik',
#  '@kapil_kausik',
#  '@kapil_kausik',
#  '@kapil_kausik',
#  '@kapil_kausik',
#  '@kapil_kausik',
#  '@kapil_kausik',
#  '@kapil_kausik',
#  '@kapil_kausik']

# %%
import pandas as pd

# %%
#getting all top 100 mentions
mentions_count=pd.Series(mentions_arr).value_counts().head(100)

# %%
mentions_count
# Out:
# @kapil_kausik    14940
# Name: count, dtype: int64
